# %% [markdown]
# # SQL Assignment 2

# %% [markdown]
# ##### 1. For an online purchasing database, create entity relationship diagrams. Create a database object from your entity diagram.

# %% [markdown]
# ![image.png](attachment:54d7fb14-56a2-4403-9206-c1d9e40db3a8.png)

# %% [markdown]
# ![image.png](attachment:da2600f2-98a4-42f3-809e-bb384d8aded7.png)

# %% [markdown]
# ##### 2. Create a SQL store process to register the use of the database, complete it with proper validation and transaction rollback and commit.

# %% [markdown]
# DELETE from Customer where State = 'Texas';
# COMMIT;

# %% [markdown]
# DELETE from Customer where State = 'Texas';
# ROLLBACK;

# %% [markdown]
# ##### 3. List the SQL aggregate function and demonstrate how to utilize it.

# %% [markdown]
#     COUNT – counts the number of elements in the group defined
#
#     SUM – calculates the sum of the given attribute/expression in the group defined
#
#     AVG – calculates the average value of the given attribute/expression in the group defined
#
#     MIN – finds the minimum in the group defined
#
#     MAX – finds the maximum in the group defined

# %% [markdown]
# ##### 4. In SQL, create a pivot query.

# %% [markdown]
# SELECT
#   product,
#   AVG(CASE WHEN price THEN price ELSE NULL END) AS avg_price
# FROM sales
# GROUP BY product

# %% [markdown]
# ##### 5. With an example, describe how to join in SQL.

# %% [markdown]
# SELECT Orders.OrderID, Customers.CustomerName, Orders.OrderDate
#
# FROM Orders
#
# INNER JOIN Customers ON Orders.CustomerID=Customers.CustomerID;

# %% [markdown]
# ##### 6. How to locate the 4th highest value in a column in a row. Create your table.

# %% [markdown]
# SELECT EmployeeID AS 4thHighestEarningEmployee
#
# FROM EmployeeSalary
#
# ORDER BY SalaryInThousands DES
# C
# LIMIT
# 1
# OFFSET 3;
