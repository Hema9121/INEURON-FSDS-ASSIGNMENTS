# %% [markdown]
# # SQL Assignment 5

# %% [markdown]
# ##### Question

# %% [markdown]
# https://drive.google.com/file/d/1gLSWYixekKNs4cgOHno5Tgjzy78_Dr09/view

# %% [markdown]
# ![image.png](attachment:bac60221-de08-47e5-99f2-12661ad4b21c.png)
