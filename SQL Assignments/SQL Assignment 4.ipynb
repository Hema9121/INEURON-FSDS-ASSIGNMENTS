# %% [markdown]
# # SQL Assignment 4

# %% [markdown]
# ##### 1. Explain different types of views. Demonstrate with suitable examples.

# %% [markdown]
# Simple View: A view based on only a single table, which doesn't contain GROUP BY clause and any functions.
#
# Complex View: A view based on multiple tables, which contain GROUP BY clause and functions.
#
# Inline View: A view based on a subquery in FROM Clause, that subquery creates a temporary table and simplifies the complex query.
#
# Materialized View: A view that stores the definition as well as data. It creates replicas of data by storing it physically.

# %% [markdown]
# ##### 2. What is the difference between function and stored procedure? Write syntax for creating functions and stored procedures.

# %% [markdown]
# Functions cannot change anything and must have at least one parameter. Also, it must return a result. Stored procedures take no parameters, can modify database objects, and need not return results. Stored procedures join SQL queries into transactions and communicate with the outside world.

# %% [markdown]
# ##### 3. What is an index in SQL? What are the different types of indexes in SQL?

# %% [markdown]
# Indexes in SQL are the individual lookup tables, which are utilized by the data set internet searcher to accelerate the general information recovery. The use of the index in SQL is to rapidly discover the data in a data set table without looking through each row of it.

# %% [markdown]
# ##### 4. Showcase an example of exception handling in SQL stored procedure.

# %% [markdown]
# ![image.png](attachment:cde4638d-9093-4796-8265-5a16fc1d92ed.png)

# %% [markdown]
# ##### 5. Create a SQL function to split strings into rows on a given character?oline

# %% [markdown]
# ##### Input String: Stephen;peter;berry;Olivier;caroline;
# ![image.png](attachment:d2854110-3230-4be0-b70e-f482a2d9fa9b.png)

# %% [markdown]
# SELECT * FROM STRING_SPLIT('Stephen;peter;berry;Olivier;caroline;
#  ' ,'; ' , 0);

# %% [markdown]
# ##### 6. What is a temporary and a variable table? Write suitable syntax to create temporary tables and variable tables.

# %% [markdown]
# Temporary tables are physical objects that are stored in the tempdb database and have statistics and indexes. Table variables are logical objects that are stored in memory and have no statistics or indexes.
